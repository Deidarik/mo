# %% [markdown]
# Метод половинного деления
# $$$$
# метод нахождения корней
# $$$$
# Фиббоначи

# %%
import math
parabolic_func= lambda x: x(x+1)
eps = 1/math.e**(-6)
max_iters=100
def show_true(operation,func, eps, a,b,n):
    result = operation(func, eps, a,b,n)

def bisect(parabolic_func, eps,lhs,rhs, max_iters):
    lhs=-5
    rhs=5
    count_iter=0
    while(count_iter<max_iters and rhs-lhs>2*eps):
        xc=(lhs+rhs)*0.5
        if(parabolic_func(xc-eps)>parabolic_func(xdc+eps)):
            lhs=xc
        else:
            rhs=xc
        count_iter+=1
    print("function probes ", count_iter)
    print("arg range ", max(rhs-lhs,-1*(rhs-lhs)))
    return (lhs+rhs)*0.5

show_true(bisect,parabolic_func, eps,lhs,rhs, max_iters)
# Out:
# function probes  0
# arg range  10

# %%
import math

func_glob =  lambda x: 2 * x ** 3 - 3 * x ** 2 - 12 * x - 5
func_first = lambda x: 6 * x ** 2 - 6 * x - 12

a1, b1 = 0.0, 10.0

e = 0.001

def half_divide_method(a, b, f):
    x = (a + b) / 2
    while math.fabs(f(x)) >= e:
        x = (a + b) / 2
        a, b = (a, x) if f(a) * f(x) < 0 else (x, b)
    return (a + b) / 2


def newtons_method(a, b, f, f1):
    x0 = (a + b) / 2
    x1 = x0 - (f(x0) / f1(x0))
    while True:
        if math.fabs(x1 - x0) < e: return x1
        x0 = x1
        x1 = x0 - (f(x0) / f1(x0))

import pylab
import numpy

X = numpy.arange(-2.0, 4.0, 0.1)
pylab.plot([x for x in X], [func_glob(x) for x in X])
pylab.grid(True)
#pylab.show()

print ('root of the equation half_divide_method %s' % half_divide_method(a1, b1, func_glob))
print ('root of the equation newtons_method %s' % newtons_method(a1, b1, func_glob, func_first))
# Out:
# root of the equation half_divide_method 3.4495162963867188
# root of the equation newtons_method 3.44948974280415
